# %% [markdown]
# # AIM 5001: Week 12 Assignment
# # Working with HTML, XML, JSON, and Web APIs
# Pujita Ravichandar

# %% [markdown]
# The books of interests that I have chosen are the following: The Oceans by Eelco J. Rohling, Classical Mechanics by John R. Taylor, and Proving Einstein Right:The Daring Expeditions That Changed How We Look at the Universe by James S. Gates and Cathie Pelletier. These are some of my favorite science books, and some books that I am currently reading. The variables I have chosen to include in my JSON, HTML, and XML files are the title, author(s), year published, and length of the books in pages. The exploration of writing the data files and uploading them into a pandas datafame is below.

# %% [markdown]
# ## Part I: Working with HTML, XML, and JSON

# %% [markdown]
# ### JSON Data
#
# The link to the github file hosting the JSON data can be found
# here: https://github.com/pujitaravi/AIM-5001/blob/master/wk12assndata.json. Writing this JSON file was a matter of following the appropriate syntax. The values were then loaded into the pandas dataframe using the `pd.read_json()` function. The resulting data frame and the accompanying code is detailed below.

# %%
#import necessary packages
import pandas as pd
import json

#use read_json to load the data into a daraframe
data = pd.read_json('https://raw.githubusercontent.com/pujitaravi/AIM-5001/master/wk12assndata.json')
data
# Out:
#                                                title  \
# 0                                         The Oceans
# 1                                Classical Mechanics
# 2  Proving Einstein Right: The Daring Expeditions...
#
#                                        author  year published  length
# 0                            Eelco J. Rohling            2017     273
# 1                              John R. Taylor            2003     808
# 2  Sylvester James Gates and Cathie Palletier            2019     451

# %% [markdown]
# ### HTML
#
# The link to my Github file hosing the HTML data can be found here: https://github.com/pujitaravi/AIM-5001/blob/master/data.html. Writing this data was amatter of following the apporpriate HTML syntax. The specifics can be seen within the contents of the link provided. These values were uploaded into a data frame by reading the html with the `read_html()` command, then the first (and in this case only) table can be called. The resulting data frame and the accompanying data is detailed below.

# %%
#read the HTML file housed within the Github repo
tables = pd.read_html('https://raw.githubusercontent.com/pujitaravi/AIM-5001/master/data.html')
len(tables)
# Out:
# 1

# %%
# the first item (and only item here) in the list is a data frame
html_data = tables[0]
type(html_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#display the first few rows of the data frame
html_data.head()
# Out:
#    Unnamed: 0                   title  \
# 0           0              The Oceans
# 1           1     Classical Mechanics
# 2           2  Proving Einstein Right
#
#                                        author  year published  length
# 0                            Eelco J. Rohling            2017     273
# 1                              John R. Taylor            2003     808
# 2  Sylvester James Gates and Cathie Pelletier            2019     451

# %% [markdown]
# ### XML
#
# The link to my Github file hosting the XML data can be found here: https://github.com/pujitaravi/AIM-5001/blob/master/week12data.xml. The specifics of the data values can be seen in the contents of the links provided. These values were uploaded into a data frame using the steps detailed in the code below. The resulting data frame and the accompanying data is detailed below.

# %%
# load the urllib.request function 
import urllib.request

# load the objectify() function from the lxml library
from lxml import objectify

# %%
# open the web page containing the data set
path, headers = urllib.request.urlretrieve('https://raw.githubusercontent.com/pujitaravi/AIM-5001/master/week12data.xml')

# objectify() is then used to parse the web page
parsed = objectify.parse(open(path))

#get a reference to the root node of the XML file
root = parsed.getroot()

# %%
# define an empty list that will be used to store the parsed data
data = []

# element from the XML data
for elt in root.book:
    el_data = {}
    for child in elt.getchildren():
        el_data[child.tag] = child.pyval
    data.append(el_data)
    
data
# Out:
# [{'title': 'The Oceans',
#   'author': 'Eelco J. Rohling',
#   'year_published': 2017,
#   'length': 273},
#  {'title': 'Classical Mechanics',
#   'author': 'John R. Taylor',
#   'year_published': 2003,
#   'length': 808},
#  {'title': 'Proving Einstein Right: The Daring Expeditions that Changed How We Look at the Universe',
#   'author': 'Sylvester James Gates and Cathie Pelletier',
#   'year_published': 2019,
#   'length': 451}]

# %%
#check the results
perf = pd.DataFrame(data)
perf.head()
# Out:
#                                                title  \
# 0                                         The Oceans
# 1                                Classical Mechanics
# 2  Proving Einstein Right: The Daring Expeditions...
#
#                                        author  year_published  length
# 0                            Eelco J. Rohling            2017     273
# 1                              John R. Taylor            2003     808
# 2  Sylvester James Gates and Cathie Pelletier            2019     451

# %% [markdown]
# ## Part II: Working with Web API's
#
# After signing up for an API Key from the New York Times Developer website, and pulled the data about the top ranking books. The API Key on the NYT website pulled JSON data. This was then explored and manipulated into a pandas dataframe that can be used to manipulate the data into a workable format. The code detailing this along with the data frame is highlighted below.

# %%
import requests

#my API key
API_key = 'wSTu5zYxHoRVVnG0eXYr4G40jTigiZev'

#url of the data with my API Key
url = 'https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key='+API_key

#send request
r = requests.get(url)

#convert the object's JSON content into a list of 
# native Python objects
json_data = r.json()

# %%
json_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2020-12-03T00:39:01-05:00',
#  'results': {'list_name': 'Hardcover Fiction',
#   'list_name_encoded': 'hardcover-fiction',
#   'bestsellers_date': '2020-11-28',
#   'published_date': '2020-12-13',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2020-12-06',
#   'display_name': 'Hardcover Fiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1524761338',
#     'primary_isbn13': '9781524761332',
#     'publisher': 'Ballantine',
#     'description': 'In a sequel to “Ready Player One,” Wade Watts discovers a technological advancement and goes on a new quest.',
#     'price': 0,
#     'title': 'READY PLAYER TWO',
#     'author': 'Ernest Cline',
#     'contributor': 'by Ernest Cline',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781524761332.jpg',
#     'book_image_width': 328,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1524761338?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1524761338', 'isbn13': '9781524761332'},
#      {'isbn10': '1524761354', 'isbn13': '9781524761356'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1524761338?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=READY+PLAYER+TWO&author=Ernest+Cline'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781524761332'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FREADY%2BPLAYER%2BTWO%2FErnest%2BCline%2F9781524761332'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781524761332'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781524761332?aff=NYT'}],
#     'book_uri': 'nyt://book/473f18d4-0433-5c42-abaa-54c7c9dd26e5'},
#    {'rank': 2,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0316420255',
#     'primary_isbn13': '9780316420259',
#     'publisher': 'Little, Brown',
#     'description': 'The 28th book in the Alex Cross series. An investigation of a double homicide sends Alex Cross to Alabama.',
#     'price': 0,
#     'title': 'DEADLY CROSS',
#     'author': 'James Patterson',
#     'contributor': 'by James Patterson',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780316420259.jpg',
#     'book_image_width': 322,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0316420255?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0316420255', 'isbn13': '9780316420259'},
#      {'isbn10': '0316497991', 'isbn13': '9780316497992'},
#      {'isbn10': '0316541761', 'isbn13': '9780316541763'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0316420255?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=DEADLY+CROSS&author=James+Patterson'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316420259'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FDEADLY%2BCROSS%2FJames%2BPatterson%2F9780316420259'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316420259'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780316420259?aff=NYT'}],
#     'book_uri': 'nyt://book/662286db-c00a-50de-9ba0-dec968f24b50'},
#    {'rank': 3,
#     'rank_last_week': 5,
#     'weeks_on_list': 9,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1538728575',
#     'primary_isbn13': '9781538728574',
#     'publisher': 'Grand Central',
#     'description': 'A doctor serving in the Navy in Afghanistan goes back to North Carolina where two women change his life.',
#     'price': 0,
#     'title': 'THE RETURN',
#     'author': 'Nicholas Sparks',
#     'contributor': 'by Nicholas Sparks',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781538728574.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1538728575?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1538728575', 'isbn13': '9781538728574'},
#      {'isbn10': '1538718979', 'isbn13': '9781538718971'},
#      {'isbn10': '1478992670', 'isbn13': '9781478992677'},
#      {'isbn10': '1549102214', 'isbn13': '9781549102219'},
#      {'isbn10': '1549106570', 'isbn13': '9781549106576'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1538728575?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+RETURN&author=Nicholas+Sparks'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538728574'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BRETURN%2FNicholas%2BSparks%2F9781538728574'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781538728574'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781538728574?aff=NYT'}],
#     'book_uri': 'nyt://book/b9bf792c-a853-54ce-8f33-7117f51be365'},
#    {'rank': 4,
#     'rank_last_week': 3,
#     'weeks_on_list': 7,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0385545967',
#     'primary_isbn13': '9780385545969',
#     'publisher': 'Doubleday',
#     'description': 'The third book in the Jake Brigance series. A 16-year-old is accused of killing a deputy in Clanton, Miss., in 1990.',
#     'price': 0,
#     'title': 'A TIME FOR MERCY',
#     'author': 'John Grisham',
#     'contributor': 'by John Grisham',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780385545969.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0385545967?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0385545967', 'isbn13': '9780385545969'},
#      {'isbn10': '0385545975', 'isbn13': '9780385545976'},
#      {'isbn10': '0593168542', 'isbn13': '9780593168547'},
#      {'isbn10': '0593168577', 'isbn13': '9780593168578'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0385545967?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=A+TIME+FOR+MERCY&author=John+Grisham'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385545969'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FA%2BTIME%2BFOR%2BMERCY%2FJohn%2BGrisham%2F9780385545969'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780385545969'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780385545969?aff=NYT'}],
#     'book_uri': 'nyt://book/33a48cf6-d7f3-5113-aa1e-6adcbb3853c3'},
#    {'rank': 5,
#     'rank_last_week': 2,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1538761696',
#     'primary_isbn13': '9781538761694',
#     'publisher': 'Grand Central',
#     'description': 'The F.B.I. agent Atlee Pine’s search for her twin sister overlaps with a military investigator’s hunt for someone involved in a global conspiracy.',
#     'price': 0,
#     'title': 'DAYLIGHT',
#     'author': 'David Baldacci',
#     'contributor': 'by David Baldacci',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781538761694.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1538761696?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1538761696', 'isbn13': '9781538761694'},
#      {'isbn10': '1538719029', 'isbn13': '9781538719022'},
#      {'isbn10': '1538761688', 'isbn13': '9781538761687'},
#      {'isbn10': '1478999322', 'isbn13': '9781478999324'},
#      {'isbn10': '1549162160', 'isbn13': '9781549162169'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1538761696?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=DAYLIGHT&author=David+Baldacci'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538761694'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FDAYLIGHT%2FDavid%2BBaldacci%2F9781538761694'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781538761694'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781538761694?aff=NYT'}],
#     'book_uri': 'nyt://book/da8e02be-ca28-5393-9abc-02be863d6cb7'},
#    {'rank': 6,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1250272610',
#     'primary_isbn13': '9781250272614',
#     'publisher': "St. Martin's",
#     'description': 'The first book in the Dragon Heart Legacy series. Breen Kelly travels through a portal in Ireland to a land of faeries and mermaids.',
#     'price': 0,
#     'title': 'THE AWAKENING',
#     'author': 'Nora Roberts',
#     'contributor': 'by Nora Roberts',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781250272614.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1250272610?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1250272610', 'isbn13': '9781250272614'},
#      {'isbn10': '1250272602', 'isbn13': '9781250272607'},
#      {'isbn10': '1250770270', 'isbn13': '9781250770271'},
#      {'isbn10': '1250770297', 'isbn13': '9781250770295'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1250272610?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+AWAKENING&author=Nora+Roberts'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250272614'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BAWAKENING%2FNora%2BRoberts%2F9781250272614'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250272614'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781250272614?aff=NYT'}],
#     'book_uri': 'nyt://book/f6cca87d-7905-5e95-943a-e72c543f314d'},
#    {'rank': 7,
#     'rank_last_week': 4,
#     'weeks_on_list': 3,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0316485624',
#     'primary_isbn13': '9780316485623',
#     'publisher': 'Little, Brown',
#     'description': 'The sixth book in the Mickey Haller series. Haller defends himself when police find the body of a former client in his car’s trunk.',
#     'price': 0,
#     'title': 'THE LAW OF INNOCENCE',
#     'author': 'Michael Connelly',
#     'contributor': 'by Michael Connelly',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780316485623.jpg',
#     'book_image_width': 322,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0316485624?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0316485624', 'isbn13': '9780316485623'},
#      {'isbn10': '0316592439', 'isbn13': '9780316592437'},
#      {'isbn10': '0316541737', 'isbn13': '9780316541732'},
#      {'isbn10': '1549129007', 'isbn13': '9781549129001'},
#      {'isbn10': '154912899X', 'isbn13': '9781549128998'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0316485624?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+LAW+OF+INNOCENCE&author=Michael+Connelly'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316485623'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BLAW%2BOF%2BINNOCENCE%2FMichael%2BConnelly%2F9780316485623'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316485623'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780316485623?aff=NYT'}],
#     'book_uri': 'nyt://book/2a92d581-b696-57c3-a866-5b983c4c07df'},
#    {'rank': 8,
#     'rank_last_week': 1,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0765326388',
#     'primary_isbn13': '9780765326386',
#     'publisher': 'Tor',
#     'description': 'The fourth book in the Stormlight Archive series. Technological discoveries and an ensuing arms race change how a war is fought.',
#     'price': 0,
#     'title': 'RHYTHM OF WAR',
#     'author': 'Brandon Sanderson',
#     'contributor': 'by Brandon Sanderson',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780765326386.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0765326388?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0765326388', 'isbn13': '9780765326386'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0765326388?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=RHYTHM+OF+WAR&author=Brandon+Sanderson'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780765326386'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FRHYTHM%2BOF%2BWAR%2FBrandon%2BSanderson%2F9780765326386'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780765326386'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780765326386?aff=NYT'}],
#     'book_uri': 'nyt://book/1f018177-46e5-5eff-83bf-2b9e9cc07290'},
#    {'rank': 9,
#     'rank_last_week': 7,
#     'weeks_on_list': 5,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': 'isbn10 mus',
#     'primary_isbn13': '9781984818461',
#     'publisher': 'Delacorte',
#     'description': 'Jack Reacher intervenes on an ambush in Tennessee and uncovers a conspiracy.',
#     'price': 0,
#     'title': 'THE SENTINEL',
#     'author': 'Lee Child and Andrew Child',
#     'contributor': 'by Lee Child and Andrew Child',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781984818461.jpg',
#     'book_image_width': 327,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1984818465?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': 'isbn10 mus', 'isbn13': '9781101599044'},
#      {'isbn10': '0593339983', 'isbn13': '9780593339985'},
#      {'isbn10': '0593339711', 'isbn13': '9780593339718'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1984818465?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+SENTINEL&author=Lee+Child+and+Andrew+Child'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781984818461'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BSENTINEL%2FLee%2BChild%2Band%2BAndrew%2BChild%2F9781984818461'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781984818461'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781984818461?aff=NYT'}],
#     'book_uri': 'nyt://book/8af67edb-c121-58bc-88ca-4fc6599ef2b6'},
#    {'rank': 10,
#     'rank_last_week': 12,
#     'weeks_on_list': 26,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0525536299',
#     'primary_isbn13': '9780525536291',
#     'publisher': 'Riverhead',
#     'description': 'The lives of twin sisters who run away from a Southern Black community at age 16 diverge as one returns and the other takes on a different racial identity but their fates intertwine.',
#     'price': 0,
#     'title': 'THE VANISHING HALF',
#     'author': 'Brit Bennett',
#     'contributor': 'by Brit Bennett',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780525536291.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0525536299?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0525536299', 'isbn13': '9780525536291'},
#      {'isbn10': '0593329430', 'isbn13': '9780593329436'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0525536299?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+VANISHING+HALF&author=Brit+Bennett'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780525536291'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BVANISHING%2BHALF%2FBrit%2BBennett%2F9780525536291'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780525536291'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780525536291?aff=NYT'}],
#     'book_uri': 'nyt://book/6db17f1d-4bd0-562a-80ef-efa2a272cf64'},
#    {'rank': 11,
#     'rank_last_week': 8,
#     'weeks_on_list': 4,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1982154837',
#     'primary_isbn13': '9781982154837',
#     'publisher': 'Atria',
#     'description': 'The 27th book in the Stephanie Plum series. Stephanie deals with a soldier of fortune from Little Havana.',
#     'price': 0,
#     'title': 'FORTUNE AND GLORY',
#     'author': 'Janet Evanovich',
#     'contributor': 'by Janet Evanovich',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781982154837.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1982154837?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1982154837', 'isbn13': '9781982154837'},
#      {'isbn10': '198216879X', 'isbn13': '9781982170219'},
#      {'isbn10': '1982170212', 'isbn13': '9781982168797'},
#      {'isbn10': '1982154861', 'isbn13': '9781982154868'},
#      {'isbn10': '1432882775', 'isbn13': '9781432882778'},
#      {'isbn10': '1797113070', 'isbn13': '9781797113074'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1982154837?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=FORTUNE+AND+GLORY&author=Janet+Evanovich'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781982154837'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FFORTUNE%2BAND%2BGLORY%2FJanet%2BEvanovich%2F9781982154837'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781982154837'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781982154837?aff=NYT'}],
#     'book_uri': 'nyt://book/adddbef7-49d1-5a23-82b6-cb83b7d030fb'},
#    {'rank': 12,
#     'rank_last_week': 13,
#     'weeks_on_list': 117,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0735219095',
#     'primary_isbn13': '9780735219090',
#     'publisher': 'Putnam',
#     'description': 'In a quiet town on the North Carolina coast in 1969, a young woman who survived alone in the marsh becomes a murder suspect.',
#     'price': 0,
#     'title': 'WHERE THE CRAWDADS SING',
#     'author': 'Delia Owens',
#     'contributor': 'by Delia Owens',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780735219090.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0735219095', 'isbn13': '9780735219090'},
#      {'isbn10': '0735219117', 'isbn13': '9780735219113'},
#      {'isbn10': '0525640371', 'isbn13': '9780525640370'},
#      {'isbn10': '0593105419', 'isbn13': '9780593105412'},
#      {'isbn10': '0593187989', 'isbn13': '9780593187982'},
#      {'isbn10': '0525640363', 'isbn13': '9780525640363'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=WHERE+THE+CRAWDADS+SING&author=Delia+Owens'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780735219090'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FWHERE%2BTHE%2BCRAWDADS%2BSING%2FDelia%2BOwens%2F9780735219090'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780735219090'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780735219090?aff=NYT'}],
#     'book_uri': 'nyt://book/053b4109-4555-5aa1-9b39-cc40549bcdf0'},
#    {'rank': 13,
#     'rank_last_week': 14,
#     'weeks_on_list': 12,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1501160834',
#     'primary_isbn13': '9781501160837',
#     'publisher': 'Atria',
#     'description': 'A failed bank robber holds a group of strangers hostage at an apartment open house.',
#     'price': 0,
#     'title': 'ANXIOUS PEOPLE',
#     'author': 'Fredrik Backman',
#     'contributor': 'by Fredrik Backman',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781501160837.jpg',
#     'book_image_width': 332,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1501160834?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1501160834', 'isbn13': '9781501160837'},
#      {'isbn10': '198216963X', 'isbn13': '9781982169633'},
#      {'isbn10': '1501160850', 'isbn13': '9781501160851'},
#      {'isbn10': '1432879715', 'isbn13': '9781432879716'},
#      {'isbn10': '1797105825', 'isbn13': '9781797105826'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1501160834?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=ANXIOUS+PEOPLE&author=Fredrik+Backman'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781501160837'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FANXIOUS%2BPEOPLE%2FFredrik%2BBackman%2F9781501160837'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781501160837'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781501160837?aff=NYT'}],
#     'book_uri': 'nyt://book/3981eb6a-8937-5dcb-848b-a3904bf779a2'},
#    {'rank': 14,
#     'rank_last_week': 0,
#     'weeks_on_list': 7,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0765387565',
#     'primary_isbn13': '9780765387561',
#     'publisher': 'Tor/Forge',
#     'description': 'A Faustian bargain comes with a curse that affects the adventure Addie LaRue has across centuries.',
#     'price': 0,
#     'title': 'THE INVISIBLE LIFE OF ADDIE LARUE',
#     'author': 'VE Schwab',
#     'contributor': 'by V.E. Schwab',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780765387561.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0765387565?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0765387565', 'isbn13': '9780765387561'},
#      {'isbn10': '1250793971', 'isbn13': '9781250793997'},
#      {'isbn10': '1250793998', 'isbn13': '9781250795182'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0765387565?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+INVISIBLE+LIFE+OF+ADDIE+LARUE&author=VE+Schwab'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780765387561'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BINVISIBLE%2BLIFE%2BOF%2BADDIE%2BLARUE%2FVE%2BSchwab%2F9780765387561'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780765387561'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780765387561?aff=NYT'}],
#     'book_uri': 'nyt://book/c9bf2d03-7b78-58d8-a9d7-a9b897d08427'},
#    {'rank': 15,
#     'rank_last_week': 6,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0399179682',
#     'primary_isbn13': '9780399179686',
#     'publisher': 'Delacorte',
#     'description': 'Just as Coco is about to graduate from Columbia, tragic events in her family send her on a journey of self-discovery.',
#     'price': 0,
#     'title': 'ALL THAT GLITTERS',
#     'author': 'Danielle Steel',
#     'contributor': 'by Danielle Steel',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780399179686.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0399179682?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0399179682', 'isbn13': '9780399179686'},
#      {'isbn10': '0399179690', 'isbn13': '9780399179693'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0399179682?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=ALL+THAT+GLITTERS&author=Danielle+Steel'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780399179686'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FALL%2BTHAT%2BGLITTERS%2FDanielle%2BSteel%2F9780399179686'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780399179686'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780399179686?aff=NYT'}],
#     'book_uri': 'nyt://book/a2ccd984-b48a-56ee-b8bd-2ca02fe706f3'}],
#   'corrections': []}}

# %%
#look at how the data is organized
json_data.keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'last_modified', 'results'])

# %%
r.json()['results'].keys()
# Out:
# dict_keys(['list_name', 'list_name_encoded', 'bestsellers_date', 'published_date', 'published_date_description', 'next_published_date', 'previous_published_date', 'display_name', 'normal_list_ends_at', 'updated', 'books', 'corrections'])

# %%
#pull the relevant data
data = r.json()['results']['books']

# %%
from pandas.io.json import json_normalize

#normalize data
df = json_normalize(data)
df.head()
# Out:
# <ipython-input-270-8f896c46e9da>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = json_normalize(data)
#    rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0     1               0              1         0       0     1524761338
# 1     2               0              1         0       0     0316420255
# 2     3               5              9         0       0     1538728575
# 3     4               3              7         0       0     0385545967
# 4     5               2              2         0       0     1538761696
#
#   primary_isbn13      publisher  \
# 0  9781524761332     Ballantine
# 1  9780316420259  Little, Brown
# 2  9781538728574  Grand Central
# 3  9780385545969      Doubleday
# 4  9781538761694  Grand Central
#
#                                          description  price  ...  \
# 0  In a sequel to “Ready Player One,” Wade Watts ...      0  ...
# 1  The 28th book in the Alex Cross series. An inv...      0  ...
# 2  A doctor serving in the Navy in Afghanistan go...      0  ...
# 3  The third book in the Jake Brigance series. A ...      0  ...
# 4  The F.B.I. agent Atlee Pine’s search for her t...      0  ...
#
#   book_image_height                                 amazon_product_url  \
# 0               500  https://www.amazon.com/dp/1524761338?tag=NYTBS...
# 1               500  https://www.amazon.com/dp/0316420255?tag=NYTBS...
# 2               500  https://www.amazon.com/dp/1538728575?tag=NYTBS...
# 3               500  https://www.amazon.com/dp/0385545967?tag=NYTBS...
# 4               500  https://www.amazon.com/dp/1538761696?tag=NYTBS...
#
#   age_group book_review_link first_chapter_link  sunday_review_link  \
# 0
# 1
# 2
# 3
# 4
#
#    article_chapter_link                                              isbns  \
# 0                        [{'isbn10': '1524761338', 'isbn13': '978152476...
# 1                        [{'isbn10': '0316420255', 'isbn13': '978031642...
# 2                        [{'isbn10': '1538728575', 'isbn13': '978153872...
# 3                        [{'isbn10': '0385545967', 'isbn13': '978038554...
# 4                        [{'isbn10': '1538761696', 'isbn13': '978153876...
#
#                                            buy_links  \
# 0  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 1  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 2  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 3  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 4  [{'name': 'Amazon', 'url': 'https://www.amazon...
#
#                                           book_uri
# 0  nyt://book/473f18d4-0433-5c42-abaa-54c7c9dd26e5
# 1  nyt://book/662286db-c00a-50de-9ba0-dec968f24b50
# 2  nyt://book/b9bf792c-a853-54ce-8f33-7117f51be365
# 3  nyt://book/33a48cf6-d7f3-5113-aa1e-6adcbb3853c3
# 4  nyt://book/da8e02be-ca28-5393-9abc-02be863d6cb7
#
# [5 rows x 26 columns]

# %%
#display the columns in the dataframe
df.columns
# Out:
# Index(['rank', 'rank_last_week', 'weeks_on_list', 'asterisk', 'dagger',
#        'primary_isbn10', 'primary_isbn13', 'publisher', 'description', 'price',
#        'title', 'author', 'contributor', 'contributor_note', 'book_image',
#        'book_image_width', 'book_image_height', 'amazon_product_url',
#        'age_group', 'book_review_link', 'first_chapter_link',
#        'sunday_review_link', 'article_chapter_link', 'isbns', 'buy_links',
#        'book_uri'],
#       dtype='object')

# %%
#make a dataframe with selected columns
df[['title', 'author', 'publisher', 'rank', 'weeks_on_list', 'isbns']]
# Out:
#                                 title                      author  \
# 0                    READY PLAYER TWO                Ernest Cline
# 1                        DEADLY CROSS             James Patterson
# 2                          THE RETURN             Nicholas Sparks
# 3                    A TIME FOR MERCY                John Grisham
# 4                            DAYLIGHT              David Baldacci
# 5                       THE AWAKENING                Nora Roberts
# 6                THE LAW OF INNOCENCE            Michael Connelly
# 7                       RHYTHM OF WAR           Brandon Sanderson
# 8                        THE SENTINEL  Lee Child and Andrew Child
# 9                  THE VANISHING HALF                Brit Bennett
# 10                  FORTUNE AND GLORY             Janet Evanovich
# 11            WHERE THE CRAWDADS SING                 Delia Owens
# 12                     ANXIOUS PEOPLE             Fredrik Backman
# 13  THE INVISIBLE LIFE OF ADDIE LARUE                   VE Schwab
# 14                  ALL THAT GLITTERS              Danielle Steel
#
#         publisher  rank  weeks_on_list  \
# 0      Ballantine     1              1
# 1   Little, Brown     2              1
# 2   Grand Central     3              9
# 3       Doubleday     4              7
# 4   Grand Central     5              2
# 5    St. Martin's     6              1
# 6   Little, Brown     7              3
# 7             Tor     8              2
# 8       Delacorte     9              5
# 9       Riverhead    10             26
# 10          Atria    11              4
# 11         Putnam    12            117
# 12          Atria    13             12
# 13      Tor/Forge    14              7
# 14      Delacorte    15              2
#
#                                                 isbns
# 0   [{'isbn10': '1524761338', 'isbn13': '978152476...
# 1   [{'isbn10': '0316420255', 'isbn13': '978031642...
# 2   [{'isbn10': '1538728575', 'isbn13': '978153872...
# 3   [{'isbn10': '0385545967', 'isbn13': '978038554...
# 4   [{'isbn10': '1538761696', 'isbn13': '978153876...
# 5   [{'isbn10': '1250272610', 'isbn13': '978125027...
# 6   [{'isbn10': '0316485624', 'isbn13': '978031648...
# 7   [{'isbn10': '0765326388', 'isbn13': '978076532...
# 8   [{'isbn10': 'isbn10 mus', 'isbn13': '978110159...
# 9   [{'isbn10': '0525536299', 'isbn13': '978052553...
# 10  [{'isbn10': '1982154837', 'isbn13': '978198215...
# 11  [{'isbn10': '0735219095', 'isbn13': '978073521...
# 12  [{'isbn10': '1501160834', 'isbn13': '978150116...
# 13  [{'isbn10': '0765387565', 'isbn13': '978076538...
# 14  [{'isbn10': '0399179682', 'isbn13': '978039917...
